# %% [markdown]
# # Speed Dating

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('Speed_Dating_Data.csv', encoding='ISO8859-1')

# %%
df.head()
# Out:
#    iid   id  gender  idg  condtn  wave  round  position  positin1  order  ...  \
# 0    1  1.0       0    1       1     1     10         7       NaN      4  ...
# 1    1  1.0       0    1       1     1     10         7       NaN      3  ...
# 2    1  1.0       0    1       1     1     10         7       NaN     10  ...
# 3    1  1.0       0    1       1     1     10         7       NaN      5  ...
# 4    1  1.0       0    1       1     1     10         7       NaN      7  ...
#
#    attr3_3  sinc3_3  intel3_3  fun3_3  amb3_3  attr5_3  sinc5_3  intel5_3  \
# 0      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 1      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 2      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 3      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 4      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
#
#    fun5_3  amb5_3
# 0     NaN     NaN
# ...

# %%
###list(df.columns)

# %%
iid_unique=df['iid'].unique()

# %%
for missing in range (0,553):
    if missing not in iid_unique:
        print (missing)
# Out:
# 0
# 118

# %%
df_attendees= df.groupby(['wave'])['id'].value_counts(sort=False).to_frame()
df_attendees= df_attendees.droplevel(1) ### to clean a second 'id' index apperence

# %%
df_attendees.index.value_counts(sort= False).plot(kind='bar', colormap= 'cividis');
plt.legend();

# %%
attendees_df= df[['id','wave', 'gender']]
attendees_df['gender']= attendees_df['gender'].map({0:'F', 1:'M'})
# Out:
# C:\Users\serda\AppData\Local\Temp\ipykernel_19844\272597215.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   attendees_df['gender']= attendees_df['gender'].map({0:'F', 1:'M'})

# %%
plt.figure(figsize=(10,6), dpi=100)

ax=sns.barplot( data=attendees_df, x='wave', y='id', hue='gender', ci=0); 

ax.set(xlabel= 'Waves no', ylabel='Attendees',title='Number of Attendees per Waves')
plt.grid(True,color='r', linestyle='-', linewidth=2, alpha= 0.2 )

plt.legend(bbox_to_anchor=[1.1, 0.9], 
           loc='center', );


plt.show()
# Out:
# C:\Users\serda\AppData\Local\Temp\ipykernel_19844\2797820046.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 0)` for the same effect.
#
#   ax=sns.barplot( data=attendees_df, x='wave', y='id', hue='gender', ci=0);

# %%
df_most_male= df[df['gender']==1][['attr1_1','sinc1_1', 'intel1_1', 'fun1_1', 'amb1_1', 'shar1_1', 'wave']]
df_most_female= df[df['gender']==0][['attr1_1','sinc1_1', 'intel1_1', 'fun1_1', 'amb1_1', 'shar1_1', 'wave']]

# %%
df_male_preferences= pd.DataFrame(df_most_male.groupby('wave').sum())
df_female_preferences= pd.DataFrame(df_most_female.groupby('wave').sum())

# %%
df_male_preferences= df_male_preferences.rename(columns={'attr1_1':'Attractive','sinc1_1': 'Sincere', 'intel1_1': 'Intelligent', 
                                    'fun1_1':'Funny','amb1_1': 'Ambitious', 'shar1_1':'Shared Interests'})
df_female_preferences= df_female_preferences.rename(columns={'attr1_1':'Attractive','sinc1_1': 'Sincere', 'intel1_1': 'Intelligent', 
                                    'fun1_1':'Funny','amb1_1': 'Ambitious', 'shar1_1':'Shared Interests'})

# %%
fig=plt.figure(figsize=(20, 10), dpi=50)

ax1 = fig.add_subplot(121)
df_male_preferences.plot(kind='bar', ax=ax1, fontsize=16)
ax1.set_xlabel('Wave number', fontsize=20)

ax1.set_title('Male Preferences', fontsize= 20, color= 'Brown')
plt.grid(True,color='gray', linestyle='-', linewidth=2, alpha= 0.1 )
plt.legend(fontsize ='xx-large');



ax2 = fig.add_subplot(122)
df_female_preferences.plot(kind='bar', ax=ax2, xlabel='Wave number', fontsize=16)
ax2.set_title('Female Preferences', fontsize= 20, color= 'Blue' )
ax2.set_xlabel('Wave number', fontsize=20)
        

plt.grid(True,color='gray', linestyle='-', linewidth=2, alpha= 0.1 )

plt.legend(fontsize ='xx-large', fancybox = True );

 
plt.tight_layout()
plt.show();

# %%
n_subplots = 21

fig, axes = plt.subplots(7, 3, figsize=(10, 20), dpi=100)

axes = axes.flatten() ### to decrease number of [ax[: nsubplots] ax values we flatten. Loop is manipulated with only i, ax number thanks to flatten

fig.suptitle('Male Preferences Waves-Based ')

for i, ax in enumerate(axes[:n_subplots]):
    df_male_preferences[i:i+1].plot(kind='bar', ax=ax, legend=None)
    ax.set_xlabel('')
    ax.set_xticklabels([]) 
    ax.set_title(f'Wave {i+1}')

plt.xlabel=None
 
plt.tight_layout()
fig.subplots_adjust(top=0.95)


plt.show()

# %%
###df_test3[df_test3.index==df_test3.index[1]].plot(ax=axes[0,0], kind='bar', legend=None)

# %%
n_subplots = 21

fig, axes = plt.subplots(7, 3, figsize=(10, 20), dpi=100)

axes = axes.flatten() ### to decrease number of [ax[: nsubplots] ax values we flatten. Loop is manipulated with only i, ax number thanks to flatten

fig.suptitle('Female Preferences Waves-Based ')


for i, ax in enumerate(axes[:n_subplots]):
    df_female_preferences[i:i+1].plot(kind='bar', ax=ax, legend=None)
    ax.set_title(f'Wave {i+1}')
 
plt.tight_layout()
fig.subplots_adjust(top=0.95)


plt.show()

# %% [markdown]
# # Preference of Partners vs Decision of Partners

# %%
df.head(2)
# Out:
#    iid   id  gender  idg  condtn  wave  round  position  positin1  order  ...  \
# 0    1  1.0       0    1       1     1     10         7       NaN      4  ...
# 1    1  1.0       0    1       1     1     10         7       NaN      3  ...
#
#    attr3_3  sinc3_3  intel3_3  fun3_3  amb3_3  attr5_3  sinc5_3  intel5_3  \
# 0      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 1      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
#
#    fun5_3  amb5_3
# 0     NaN     NaN
# 1     NaN     NaN
#
# [2 rows x 195 columns]

# %%
pf_o_att: 	partner’s stated preference at Time 1 (attr1_1) for all 6 attributes

dec_o: 		decision of partner the night of event
    
Columns concerned: 
    
 'pf_o_att',     
 'pf_o_sin',
 'pf_o_int',
 'pf_o_fun',
 'pf_o_amb',
 'pf_o_sha'
    
    attr1_2 
Attractive
sinc1_2
Sincere
intel1_2
Intelligent
fun1_2
Fun
amb1_2
Ambitious
shar1_2
Has shared interests/hobbies

    
      *** 'dec_o',
 'attr_o',
 'sinc_o',
 'intel_o',
 'fun_o',
 'amb_o',
 'shar_o',
    
    also check :
 'like_o',
 'prob_o',
 'met_o',

# %%
df_preferences = df[[ 'pf_o_att',     
 'pf_o_sin',
 'pf_o_int',
 'pf_o_fun',
 'pf_o_amb',
 'pf_o_sha',
 'gender',
 ]]

# %%
df_decisions = df[[ 'attr_o',
 'sinc_o',
 'intel_o',
 'fun_o',
 'amb_o',
 'shar_o',
'gender',
]]

# %%
df_before_pre= df_preferences.rename(columns={'pf_o_att':'Attractive','pf_o_sin': 'Sincere', 'pf_o_int': 'Intelligent', 
                                    'pf_o_fun':'Funny','pf_o_amb': 'Ambitious', 'pf_o_sha':'Shared Interests'})
df_after_pre= df_decisions.rename(columns={'attr_o':'Attractive','sinc_o': 'Sincere', 'intel_o': 'Intelligent', 
                                    'fun_o':'Funny','amb_o': 'Ambitious', 'shar_o':'Shared Interests'})

# %%
'attr_o',
 'sinc_o',
 'intel_o',
 'fun_o',
 'amb_o',
 'shar_o',

# %%
df_before_pre
# Out:
#       Attractive  Sincere  Intelligent  Funny  Ambitious  Shared Interests  \
# 0           35.0     20.0         20.0   20.0        0.0               5.0
# 1           60.0      0.0          0.0   40.0        0.0               0.0
# 2           19.0     18.0         19.0   18.0       14.0              12.0
# 3           30.0      5.0         15.0   40.0        5.0               5.0
# 4           30.0     10.0         20.0   10.0       10.0              20.0
# ...          ...      ...          ...    ...        ...               ...
# 8373        10.0     10.0         30.0   20.0       10.0              15.0
# 8374        50.0     20.0         10.0    5.0       10.0               5.0
# 8375        40.0     10.0         30.0   10.0       10.0               NaN
# 8376        10.0     25.0         25.0   10.0       10.0              20.0
# 8377        20.0     20.0         10.0   15.0        5.0              30.0
#
#       gender
# 0          0
# 1          0
# 2          0
# ...

# %%
dist_before= df_before_pre.groupby('gender').sum()
dist_after = df_after_pre.groupby('gender').sum()

# %%
dist_after
# Out:
#         Attractive  Sincere  Intelligent    Funny  Ambitious  Shared Interests
# gender
# 0          26381.9  29272.5      29420.0  26191.5    25322.0           20469.0
# 1          24169.0  28782.5      30065.0  25128.5    26573.5           19508.5

# %%
dist_before
# Out:
#         Attractive   Sincere  Intelligent     Funny  Ambitious  \
# gender
# 0        111986.13  68694.47     81389.00  73833.85   35466.45
# 1         74477.80  75508.16     86635.32  70732.58   52912.29
#
#         Shared Interests
# gender
# 0               45591.77
# 1               52125.31

# %%
grp_prefer_df
# Out:
#          pf_o_att  pf_o_sin  pf_o_int  pf_o_fun  pf_o_amb  pf_o_sha
# gender
# 0       111986.13  68694.47  81389.00  73833.85  35466.45  45591.77
# 1        74477.80  75508.16  86635.32  70732.58  52912.29  52125.31

# %%
fig= plt.figure(figsize=(10,8), dpi=50)

ax1= fig.add_subplot(1,2,1)


ax1.set_title('Before', fontsize=20)
dist_before.plot(kind='bar', ax=ax1, xlabel= 'Gender');
ax1.set_xticklabels(['Female', 'Male'], fontsize=12)
plt.grid(True,color='gray', linestyle='-', linewidth=2, alpha= 0.1 )



ax2 = fig.add_subplot(1,2,2)

ax2.set_title('After', fontsize=20)
dist_after.plot(kind='bar', ax=ax2, xlabel= 'Gender');

ax2.set_xticklabels(['Female','Male'], fontsize=16)
ax2.legend(bbox_to_anchor=(0.5,0.5, 1, 0.5))

plt.grid(True,color='gray', linestyle='-', linewidth=2, alpha= 0.1 )

fig.suptitle("Total Scorings", fontsize=16, y=0.93)


plt.show()

# %%
###Importance of Atrractiveness - Before and After :

# %%
before_vs_after_Att=pd.DataFrame(df_before_pre['Attractive'])

# %%
before_vs_after_Att
# Out:
#       Attractive
# 0           35.0
# 1           60.0
# 2           19.0
# 3           30.0
# 4           30.0
# ...          ...
# 8373        10.0
# 8374        50.0
# 8375        40.0
# 8376        10.0
# 8377        20.0
#
# [8378 rows x 1 columns]

# %%
before_vs_after_Att.rename(columns={'Attractive':'Before'}, inplace=True)

# %%
before_vs_after_Att['After']=df_after_pre['Attractive']

# %%
before_vs_after_Att.sum().plot(kind='pie');
plt.show();

# %%
dist_before[['pf_o_att','pf_o_sin','pf_o_int','pf_o_fun','pf_o_amb','pf_o_sha']]
counts.plot(kind='bar')
plt.show()

# %%
dist_after = df_after_pre.groupby('gender').sum().value_counts()

# %%
dist_after1 = df_after_pre.groupby(['gender']).sum().value_counts().reset_index(name='count')

# %%
dist_after2= df_after_pre.groupby('gender').sum().value_counts().reset_index(name='count')

# %%
dist_after2.plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
dist_after1.plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
dist_after3= df_after_pre.groupby('gender').sum().value_counts().reset_index()

# %%
dist_after3.reset_index
# Out:
# Attractive  Sincere  Intelligent  Funny    Ambitious  Shared Interests
# 24169.0     28782.5  30065.0      25128.5  26573.5    19508.5             1
# 26381.9     29272.5  29420.0      26191.5  25322.0    20469.0             1
# dtype: int64

# %%
sns.countplot(df_decisions);
